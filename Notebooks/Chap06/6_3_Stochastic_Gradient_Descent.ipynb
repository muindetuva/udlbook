# %% [markdown]
# <a href="https://colab.research.google.com/github/muindetuva/udlbook/blob/6_3/Notebooks/Chap06/6_3_Stochastic_Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 6.3: Stochastic gradient descent**
#
# This notebook investigates gradient descent and stochastic gradient descent and recreates figure 6.5 from the book
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap

# %%
# Let's create our training data of 30 pairs {x_i, y_i}
# We'll try to fit the Gabor model to these data
data = np.array([[-1.920e+00,-1.422e+01,1.490e+00,-1.940e+00,-2.389e+00,-5.090e+00,
                 -8.861e+00,3.578e+00,-6.010e+00,-6.995e+00,3.634e+00,8.743e-01,
                 -1.096e+01,4.073e-01,-9.467e+00,8.560e+00,1.062e+01,-1.729e-01,
                  1.040e+01,-1.261e+01,1.574e-01,-1.304e+01,-2.156e+00,-1.210e+01,
                 -1.119e+01,2.902e+00,-8.220e+00,-1.179e+01,-8.391e+00,-4.505e+00],
                  [-1.051e+00,-2.482e-02,8.896e-01,-4.943e-01,-9.371e-01,4.306e-01,
                  9.577e-03,-7.944e-02 ,1.624e-01,-2.682e-01,-3.129e-01,8.303e-01,
                  -2.365e-02,5.098e-01,-2.777e-01,3.367e-01,1.927e-01,-2.222e-01,
                  6.352e-02,6.888e-03,3.224e-02,1.091e-02,-5.706e-01,-5.258e-02,
                  -3.666e-02,1.709e-01,-4.805e-02,2.008e-01,-1.904e-01,5.952e-01]])

# %%
# Let's define our model
def model(phi,x):
  sin_component = np.sin(phi[0] + 0.06 * phi[1] * x)
  gauss_component = np.exp(-(phi[0] + 0.06 * phi[1] * x) * (phi[0] + 0.06 * phi[1] * x) / 32)
  y_pred= sin_component * gauss_component
  return y_pred

# %%
# Draw model
def draw_model(data,model,phi,title=None):
  x_model = np.arange(-15,15,0.1)
  y_model = model(phi,x_model)

  fix, ax = plt.subplots()
  ax.plot(data[0,:],data[1,:],'bo')
  ax.plot(x_model,y_model,'m-')
  ax.set_xlim([-15,15]);ax.set_ylim([-1,1])
  ax.set_xlabel('x'); ax.set_ylabel('y')
  if title is not None:
    ax.set_title(title)
  plt.show()

# %%
# Initialize the parameters and draw the model
phi = np.zeros((2,1))
phi[0] =  -5     # Horizontal offset
phi[1] =  25     # Frequency
draw_model(data,model,phi, "Initial parameters")

# %% [markdown]
# Now let's compute the sum of squares loss for the training data

# %%
def compute_loss(data_x, data_y, model, phi):
  # TODO -- First make model predictions from data x
  pred_y = model(phi, data_x)
  # TODO -- Then compute the squared difference between the predictions and true y values
  squared_diffs = (pred_y - data_y) ** 2
  # TODO -- Then sum them all and return
  loss = np.sum(squared_diffs)

  return loss

# %% [markdown]
# Let's just test that we got that right

# %%
loss = compute_loss(data[0,:],data[1,:],model,np.array([[0.6],[-0.2]]))
print('Your loss = %3.3f, Correct loss = %3.3f'%(loss, 16.419))
# Out:
# Your loss = 16.419, Correct loss = 16.419

# %% [markdown]
# Now let's plot the whole loss function

# %%
def draw_loss_function(compute_loss, data,  model, phi_iters = None):
  # Define pretty colormap
  my_colormap_vals_hex =('2a0902', '2b0a03', '2c0b04', '2d0c05', '2e0c06', '2f0d07', '300d08', '310e09', '320f0a', '330f0b', '34100b', '35110c', '36110d', '37120e', '38120f', '39130f', '3a1410', '3b1411', '3c1511', '3d1612', '3e1613', '3f1713', '401714', '411814', '421915', '431915', '451a16', '461b16', '471b17', '481c17', '491d18', '4a1d18', '4b1e19', '4c1f19', '4d1f1a', '4e201b', '50211b', '51211c', '52221c', '53231d', '54231d', '55241e', '56251e', '57261f', '58261f', '592720', '5b2821', '5c2821', '5d2922', '5e2a22', '5f2b23', '602b23', '612c24', '622d25', '632e25', '652e26', '662f26', '673027', '683027', '693128', '6a3229', '6b3329', '6c342a', '6d342a', '6f352b', '70362c', '71372c', '72372d', '73382e', '74392e', '753a2f', '763a2f', '773b30', '783c31', '7a3d31', '7b3e32', '7c3e33', '7d3f33', '7e4034', '7f4134', '804235', '814236', '824336', '834437', '854538', '864638', '874739', '88473a', '89483a', '8a493b', '8b4a3c', '8c4b3c', '8d4c3d', '8e4c3e', '8f4d3f', '904e3f', '924f40', '935041', '945141', '955242', '965343', '975343', '985444', '995545', '9a5646', '9b5746', '9c5847', '9d5948', '9e5a49', '9f5a49', 'a05b4a', 'a15c4b', 'a35d4b', 'a45e4c', 'a55f4d', 'a6604e', 'a7614e', 'a8624f', 'a96350', 'aa6451', 'ab6552', 'ac6552', 'ad6653', 'ae6754', 'af6855', 'b06955', 'b16a56', 'b26b57', 'b36c58', 'b46d59', 'b56e59', 'b66f5a', 'b7705b', 'b8715c', 'b9725d', 'ba735d', 'bb745e', 'bc755f', 'bd7660', 'be7761', 'bf7862', 'c07962', 'c17a63', 'c27b64', 'c27c65', 'c37d66', 'c47e67', 'c57f68', 'c68068', 'c78169', 'c8826a', 'c9836b', 'ca846c', 'cb856d', 'cc866e', 'cd876f', 'ce886f', 'ce8970', 'cf8a71', 'd08b72', 'd18c73', 'd28d74', 'd38e75', 'd48f76', 'd59077', 'd59178', 'd69279', 'd7937a', 'd8957b', 'd9967b', 'da977c', 'da987d', 'db997e', 'dc9a7f', 'dd9b80', 'de9c81', 'de9d82', 'df9e83', 'e09f84', 'e1a185', 'e2a286', 'e2a387', 'e3a488', 'e4a589', 'e5a68a', 'e5a78b', 'e6a88c', 'e7aa8d', 'e7ab8e', 'e8ac8f', 'e9ad90', 'eaae91', 'eaaf92', 'ebb093', 'ecb295', 'ecb396', 'edb497', 'eeb598', 'eeb699', 'efb79a', 'efb99b', 'f0ba9c', 'f1bb9d', 'f1bc9e', 'f2bd9f', 'f2bfa1', 'f3c0a2', 'f3c1a3', 'f4c2a4', 'f5c3a5', 'f5c5a6', 'f6c6a7', 'f6c7a8', 'f7c8aa', 'f7c9ab', 'f8cbac', 'f8ccad', 'f8cdae', 'f9ceb0', 'f9d0b1', 'fad1b2', 'fad2b3', 'fbd3b4', 'fbd5b6', 'fbd6b7', 'fcd7b8', 'fcd8b9', 'fcdaba', 'fddbbc', 'fddcbd', 'fddebe', 'fddfbf', 'fee0c1', 'fee1c2', 'fee3c3', 'fee4c5', 'ffe5c6', 'ffe7c7', 'ffe8c9', 'ffe9ca', 'ffebcb', 'ffeccd', 'ffedce', 'ffefcf', 'fff0d1', 'fff2d2', 'fff3d3', 'fff4d5', 'fff6d6', 'fff7d8', 'fff8d9', 'fffada', 'fffbdc', 'fffcdd', 'fffedf', 'ffffe0')
  my_colormap_vals_dec = np.array([int(element,base=16) for element in my_colormap_vals_hex])
  r = np.floor(my_colormap_vals_dec/(256*256))
  g = np.floor((my_colormap_vals_dec - r *256 *256)/256)
  b = np.floor(my_colormap_vals_dec - r * 256 *256 - g * 256)
  my_colormap = ListedColormap(np.vstack((r,g,b)).transpose()/255.0)

  # Make grid of offset/frequency values to plot
  offsets_mesh, freqs_mesh = np.meshgrid(np.arange(-10,10.0,0.1), np.arange(2.5,22.5,0.1))
  loss_mesh = np.zeros_like(freqs_mesh)
  # Compute loss for every set of parameters
  for idslope, slope in np.ndenumerate(freqs_mesh):
     loss_mesh[idslope] = compute_loss(data[0,:], data[1,:], model, np.array([[offsets_mesh[idslope]], [slope]]))

  fig,ax = plt.subplots()
  fig.set_size_inches(8,8)
  ax.contourf(offsets_mesh,freqs_mesh,loss_mesh,256,cmap=my_colormap)
  ax.contour(offsets_mesh,freqs_mesh,loss_mesh,20,colors=['#80808080'])
  if phi_iters is not None:
    ax.plot(phi_iters[0,:], phi_iters[1,:],'go-')
  ax.set_ylim([2.5,22.5])
  ax.set_xlabel('Offset $\phi_{0}$'); ax.set_ylabel('Frequency, $\phi_{1}$')
  plt.show()

# %%
draw_loss_function(compute_loss, data, model)

# %% [markdown]
# Now let's compute the gradient vector for a given set of parameters:
#
# \begin{equation}
# \frac{\partial L}{\partial \boldsymbol\phi} = \begin{bmatrix}\frac{\partial L}{\partial \phi_0} \\\frac{\partial L}{\partial \phi_1} \end{bmatrix}.
# \end{equation}

# %%
# These came from writing out the expression for the sum of squares loss and taking the
# derivative with respect to phi0 and phi1. It was a lot of hassle to get it right!
def gabor_deriv_phi0(data_x,data_y,phi0, phi1):
    x = 0.06 * phi1 * data_x + phi0
    y = data_y
    cos_component = np.cos(x)
    sin_component = np.sin(x)
    gauss_component = np.exp(-0.5 * x *x / 16)
    deriv = cos_component * gauss_component - sin_component * gauss_component * x / 16
    deriv = 2* deriv * (sin_component * gauss_component - y)
    return np.sum(deriv)

def gabor_deriv_phi1(data_x, data_y,phi0, phi1):
    x = 0.06 * phi1 * data_x + phi0
    y = data_y
    cos_component = np.cos(x)
    sin_component = np.sin(x)
    gauss_component = np.exp(-0.5 * x *x / 16)
    deriv = 0.06 * data_x * cos_component * gauss_component - 0.06 * data_x*sin_component * gauss_component * x / 16
    deriv = 2*deriv * (sin_component * gauss_component - y)
    return np.sum(deriv)

def compute_gradient(data_x, data_y, phi):
    dl_dphi0 = gabor_deriv_phi0(data_x, data_y, phi[0],phi[1])
    dl_dphi1 = gabor_deriv_phi1(data_x, data_y, phi[0],phi[1])
    # Return the gradient
    return np.array([[dl_dphi0],[dl_dphi1]])

# %% [markdown]
# We can check we got this right using a trick known as **finite differences**.  If we evaluate the function and then change one of the parameters by a very small amount and normalize by that amount, we get an approximation to the gradient, so:
#
# \begin{align}
# \frac{\partial L}{\partial \phi_{0}}&\approx & \frac{L[\phi_0+\delta, \phi_1]-L[\phi_0, \phi_1]}{\delta}\\
# \frac{\partial L}{\partial \phi_{1}}&\approx & \frac{L[\phi_0, \phi_1+\delta]-L[\phi_0, \phi_1]}{\delta}
# \end{align}
#
# We can't do this when there are many parameters;  for a million parameters, we would have to evaluate the loss function two million times, and usually computing the gradients directly is much more efficient.

# %%
# Compute the gradient using your function
gradient = compute_gradient(data[0,:],data[1,:], phi)
print("Your gradients: (%3.3f,%3.3f)"%(gradient[0],gradient[1]))
# Approximate the gradients with finite differences
delta = 0.0001
dl_dphi0_est = (compute_loss(data[0,:],data[1,:],model,phi+np.array([[delta],[0]])) - \
                    compute_loss(data[0,:],data[1,:],model,phi))/delta
dl_dphi1_est = (compute_loss(data[0,:],data[1,:],model,phi+np.array([[0],[delta]])) - \
                    compute_loss(data[0,:],data[1,:],model,phi))/delta
print("Approx gradients: (%3.3f,%3.3f)"%(dl_dphi0_est,dl_dphi1_est))
# Out:
# Your gradients: (3.344,0.519)
# Approx gradients: (3.344,0.519)

# %% [markdown]
# Now we are ready to perform gradient descent.  We'll need to use our line search routine from Notebook 6.1, which I've reproduced here plus the helper function loss_function_1D that converts from a 2D problem to a 1D problem

# %%
def loss_function_1D(dist_prop, data, model, phi_start, gradient):
  # Return the loss after moving this far
  return compute_loss(data[0,:], data[1,:], model, phi_start+ gradient * dist_prop)

def line_search(data, model, phi, gradient, thresh=.00001, max_dist = 0.1, max_iter = 15, verbose=False):
    # Initialize four points along the range we are going to search
    a = 0
    b = 0.33 * max_dist
    c = 0.66 * max_dist
    d = 1.0 * max_dist
    n_iter = 0

    # While we haven't found the minimum closely enough
    while np.abs(b-c) > thresh and n_iter < max_iter:
        # Increment iteration counter (just to prevent an infinite loop)
        n_iter = n_iter+1
        # Calculate all four points
        lossa = loss_function_1D(a, data, model, phi,gradient)
        lossb = loss_function_1D(b, data, model, phi,gradient)
        lossc = loss_function_1D(c, data, model, phi,gradient)
        lossd = loss_function_1D(d, data, model, phi,gradient)

        if verbose:
          print('Iter %d, a=%3.3f, b=%3.3f, c=%3.3f, d=%3.3f'%(n_iter, a,b,c,d))
          print('a %f, b%f, c%f, d%f'%(lossa,lossb,lossc,lossd))

        # Rule #1 If point A is less than points B, C, and D then halve points B,C, and D
        if np.argmin((lossa,lossb,lossc,lossd))==0:
          b = b/2
          c = c/2
          d = d/2
          continue;

        # Rule #2 If point b is less than point c then
        #                     point d becomes point c, and
        #                     point b becomes 1/3 between a and new d
        #                     point c becomes 2/3 between a and new d
        if lossb < lossc:
          d = c
          b = a+ (d-a)/3
          c = a+ 2*(d-a)/3
          continue

        # Rule #2 If point c is less than point b then
        #                     point a becomes point b, and
        #                     point b becomes 1/3 between new a and d
        #                     point c becomes 2/3 between new a and d
        a = b
        b = a+ (d-a)/3
        c = a+ 2*(d-a)/3

    # Return average of two middle points
    return (b+c)/2.0

# %%
def gradient_descent_step(phi, data,  model):
  # Step 1:  Compute the gradient
  gradient = compute_gradient(data[0,:],data[1,:], phi)
  # Step 2:  Update the parameters -- note we want to search in the negative (downhill direction)
  alpha = line_search(data, model, phi, gradient*-1, max_dist = 2.0)
  phi = phi - alpha * gradient
  return phi

# %%
# Initialize the parameters
n_steps = 21
phi_all = np.zeros((2,n_steps+1))
phi_all[0,0] = -1.5
phi_all[1,0] = 8.5

# Measure loss and draw initial model
loss =  compute_loss(data[0,:], data[1,:], model, phi_all[:,0:1])
draw_model(data,model,phi_all[:,0:1], "Initial parameters, Loss = %f"%(loss))

for c_step in range (n_steps):
  # Do gradient descent step
  phi_all[:,c_step+1:c_step+2] = gradient_descent_step(phi_all[:,c_step:c_step+1],data, model)
  # Measure loss and draw model every 4th step
  if c_step % 4 == 0:
    loss =  compute_loss(data[0,:], data[1,:], model, phi_all[:,c_step+1:c_step+2])
    draw_model(data,model,phi_all[:,c_step+1], "Iteration %d, loss = %f"%(c_step+1,loss))

draw_loss_function(compute_loss, data, model,phi_all)

# %%
# TODO Experiment with starting the optimization in the previous cell in different places
# and show that it heads to a local minimum if we don't start it in the right valley
# Starting in a different valley
phi_all[0, 0] = 10  # Adjusted initial horizontal offset
phi_all[1, 0] = 15  # Adjusted initial frequency

# Reset the loss history and phi_all for storage if necessary
phi_all = np.zeros((2, n_steps+1))
phi_all[:, 0] = [10, 15]

# Rerun the optimization loop
for c_step in range(n_steps):
    phi_all[:, c_step+1:c_step+2] = gradient_descent_step(phi_all[:, c_step:c_step+1], data, model)
    if c_step % 4 == 0:
        loss = compute_loss(data[0, :], data[1, :], model, phi_all[:, c_step+1:c_step+2])
        draw_model(data, model, phi_all[:, c_step+1], f"Iteration {c_step+1}, loss = {loss}")

# Finally, visualize the path of the parameters
draw_loss_function(compute_loss, data, model, phi_all)

# %%
def gradient_descent_step_fixed_learning_rate(phi, data, alpha):
  # TODO -- fill in this routine so that we take a fixed size step of size alpha without using line search
  gradient = compute_gradient(data[0, :], data[1, :], phi)

  phi = phi - alpha * gradient

  return phi

# %%
# Initialize the parameters
n_steps = 21
phi_all = np.zeros((2,n_steps+1))
phi_all[0,0] = -1.5
phi_all[1,0] = 8.5

# Measure loss and draw initial model
loss =  compute_loss(data[0,:], data[1,:], model, phi_all[:,0:1])
draw_model(data,model,phi_all[:,0:1], "Initial parameters, Loss = %f"%(loss))

for c_step in range (n_steps):
  # Do gradient descent step
  phi_all[:,c_step+1:c_step+2] = gradient_descent_step_fixed_learning_rate(phi_all[:,c_step:c_step+1],data, alpha =0.2)
  # Measure loss and draw model every 4th step
  if c_step % 4 == 0:
    loss =  compute_loss(data[0,:], data[1,:], model, phi_all[:,c_step+1:c_step+2])
    draw_model(data,model,phi_all[:,c_step+1], "Iteration %d, loss = %f"%(c_step+1,loss))

draw_loss_function(compute_loss, data, model,phi_all)

# %%
# TODO Experiment with the learning rate, alpha.
# What happens if you set it too large?
# What happens if you set it too small?
# Example: Trying different learning rates
learning_rates = [0.01, 0.2, 1.0]  # Example learning rates: too small, moderate, too large
for alpha in learning_rates:
    # Re-initialize phi for each experiment
    phi = np.array([[-1.5], [8.5]])
    print(f"Trying learning rate: {alpha}")
    for step in range(n_steps):
        phi = gradient_descent_step_fixed_learning_rate(phi, data, alpha)
        if step % 4 == 0:
            loss = compute_loss(data[0, :], data[1, :], model, phi)
            print(f"Step {step}, Loss: {loss}")
    # Optionally, draw the final model for this learning rate
    draw_model(data, model, phi, f"Final parameters with alpha = {alpha}, Loss = {loss}")
    print("\n\n\n")
# Out:
# Trying learning rate: 0.01
# Step 0, Loss: 11.64831957032083
# Step 4, Loss: 11.464228752686155
# Step 8, Loss: 11.289708428958354
# Step 12, Loss: 11.122882388101338
# Step 16, Loss: 10.961569227960153
# Step 20, Loss: 10.803370350450741
# Step 24, Loss: 10.645722277823477
# Step 28, Loss: 10.485948302597619
# Step 32, Loss: 10.321350760496257
# Step 36, Loss: 10.149389748390861
# Step 40, Loss: 9.967987606827695
# Trying learning rate: 0.2
# Step 0, Loss: 10.800399088988513
# Step 4, Loss: 7.7163159247764375
# Step 8, Loss: 4.818621086609084
# Step 12, Loss: 2.7500135399326613
# Step 16, Loss: 1.8253038783103974
# Step 20, Loss: 1.3883756768481212
# Step 24, Loss: 1.1411784526048678
# Step 28, Loss: 0.9847735103318749
# Step 32, Loss: 0.8806565378199048
# Step 36, Loss: 0.8110177600044004
# Step 40, Loss: 0.7694829096973212
# Trying learning rate: 1.0
# Step 0, Loss: 10.568146553128082
# Step 4, Loss: 5.455112654358381
# Step 8, Loss: 5.387801789158741
# Step 12, Loss: 5.386032493869061
# Step 16, Loss: 5.384849023282917
# Step 20, Loss: 5.384055810785028
# Step 24, Loss: 5.383523061668834
# Step 28, Loss: 5.383164514924776
# Step 32, Loss: 5.382922746416898
# Step 36, Loss: 5.382759439936198
# Step 40, Loss: 5.382648963792592

# %%
def stochastic_gradient_descent_step(phi, data, alpha, batch_size):
    # TODO -- fill in this routine so that we take a fixed size step of size alpha but only using a subset (batch) of the data
    # at each step
    # You can use the function np.random.permutation to generate a random permutation of the n_data = data.shape[1] indices
    # and then just choose the first n=batch_size of these indices.  Then compute the gradient update
    # from just the data with these indices.   More properly, you should sample without replacement, but this will do for now.
    # Number of data points
    n_data = data.shape[1]

    # Generate a random permutation of indices and select the first batch_size indices
    indices = np.random.permutation(n_data)[:batch_size]

    # Extract the batch data
    data_x_batch = data[0, indices]
    data_y_batch = data[1, indices]

    # Compute the gradient using only the batch data
    gradient = compute_gradient(data_x_batch, data_y_batch, phi)

    # Update the parameters phi by taking a step in the direction opposite to the gradient
    phi = phi - alpha * gradient

    return phi

# %%
# Set the random number generator so you always get same numbers (disable if you don't want this)
np.random.seed(1)
# Initialize the parameters
n_steps = 41
phi_all = np.zeros((2,n_steps+1))
phi_all[0,0] = 3.5
phi_all[1,0] = 6.5

# Measure loss and draw initial model
loss =  compute_loss(data[0,:], data[1,:], model, phi_all[:,0:1])
draw_model(data,model,phi_all[:,0:1], "Initial parameters, Loss = %f"%(loss))

for c_step in range (n_steps):
  # Do gradient descent step
  phi_all[:,c_step+1:c_step+2] = stochastic_gradient_descent_step(phi_all[:,c_step:c_step+1],data, alpha =0.8, batch_size=5)
  # Measure loss and draw model every 8th step
  if c_step % 8 == 0:
    loss =  compute_loss(data[0,:], data[1,:], model, phi_all[:,c_step+1:c_step+2])
    draw_model(data,model,phi_all[:,c_step+1], "Iteration %d, loss = %f"%(c_step+1,loss))

draw_loss_function(compute_loss, data, model,phi_all)

# %%
# TODO -- Experiment with different learning rates, starting points, batch sizes, number of steps.  Get a feel for this.
learning_rates = [0.1, 0.5, 0.8]
batch_sizes = [5, 10, data.shape[1]]  # Including the full batch size for comparison
initial_phi = [
    np.array([[3.5], [6.5]]),
    np.array([[0.0], [10.0]]),
    np.array([[5.0], [5.0]])
]

for phi_start in initial_phi:
    for alpha in learning_rates:
        for batch_size in batch_sizes:
            # Reinitialize parameters
            phi = phi_start.copy()
            print(f"Starting point: {phi.T}, Learning rate: {alpha}, Batch size: {batch_size}")

            # Perform SGD steps
            for step in range(n_steps):
                phi = stochastic_gradient_descent_step(phi, data, alpha, batch_size)

                if step % 10 == 0:
                    loss = compute_loss(data[0, :], data[1, :], model, phi)
                    print(f"Step {step}, Loss: {loss}")
            print("\n\n\n")
# Out:
# Starting point: [[3.5 6.5]], Learning rate: 0.1, Batch size: 5
# Step 0, Loss: 17.975130809118678
# Step 10, Loss: 12.137442136275755
# Step 20, Loss: 11.188828603249222
# Step 30, Loss: 11.118645514559448
# Step 40, Loss: 10.898979363950327
#
#
#
#
# Starting point: [[3.5 6.5]], Learning rate: 0.1, Batch size: 10
# Step 0, Loss: 16.658617832239766
# Step 10, Loss: 12.283717441068394
# Step 20, Loss: 11.54044356137384
# Step 30, Loss: 11.165435329013148
# Step 40, Loss: 10.762933191525185
#
#
#
#
# Starting point: [[3.5 6.5]], Learning rate: 0.1, Batch size: 30
# Step 0, Loss: 15.7317506956058
# Step 10, Loss: 10.595409902349086
# Step 20, Loss: 10.090434207071986
# Step 30, Loss: 9.98834789052279
# Step 40, Loss: 9.96712353335102
#
#
#
#
# Starting point: [[3.5 6.5]], Learning rate: 0.5, Batch size: 5
# Step 0, Loss: 12.514523140842838
# Step 10, Loss: 8.580471151656463
# Step 20, Loss: 7.545834132589353
# Step 30, Loss: 7.639299190653287
# Step 40, Loss: 6.981600756604994
#
#
#
#
# Starting point: [[3.5 6.5]], Learning rate: 0.5, Batch size: 10
# Step 0, Loss: 14.011121609534719
# Step 10, Loss: 7.13090997618356
# Step 20, Loss: 6.042607900496184
# Step 30, Loss: 6.033339080764241
# Step 40, Loss: 5.950235328810457
#
#
#
#
# Starting point: [[3.5 6.5]], Learning rate: 0.5, Batch size: 30
# Step 0, Loss: 11.783507471697233
# Step 10, Loss: 10.86610098686842
# Step 20, Loss: 10.520598510530444
# Step 30, Loss: 10.88226326348923
# Step 40, Loss: 11.228916451577632
#
#
#
#
# Starting point: [[3.5 6.5]], Learning rate: 0.8, Batch size: 5
# Step 0, Loss: 17.69579639402719
# Step 10, Loss: 10.214679870273756
# Step 20, Loss: 5.960368014162577
# Step 30, Loss: 5.8582566421205176
# Step 40, Loss: 5.788400484206472
#
#
#
#
# Starting point: [[3.5 6.5]], Learning rate: 0.8, Batch size: 10
# Step 0, Loss: 11.651325484193922
# Step 10, Loss: 7.425282367258894
# Step 20, Loss: 5.611711524389549
# Step 30, Loss: 5.616913626724315
# Step 40, Loss: 5.609731720333125
#
#
#
#
# Starting point: [[3.5 6.5]], Learning rate: 0.8, Batch size: 30
# Step 0, Loss: 10.05225454194729
# Step 10, Loss: 5.588584905543374
# Step 20, Loss: 5.383100581641695
# Step 30, Loss: 5.381827523424789
# Step 40, Loss: 5.381688924319446
#
#
#
#
# Starting point: [[ 0. 10.]], Learning rate: 0.1, Batch size: 5
# Step 0, Loss: 6.066159510800135
# Step 10, Loss: 5.3213139446377
# Step 20, Loss: 4.736527525313066
# Step 30, Loss: 4.03713410442489
# Step 40, Loss: 3.7397786091209007
#
#
#
#
# Starting point: [[ 0. 10.]], Learning rate: 0.1, Batch size: 10
# Step 0, Loss: 6.117514811152246
# Step 10, Loss: 5.347257176112357
# Step 20, Loss: 3.792557451698604
# Step 30, Loss: 2.9476077578904465
# Step 40, Loss: 2.5090000581855096
#
#
#
#
# Starting point: [[ 0. 10.]], Learning rate: 0.1, Batch size: 30
# Step 0, Loss: 5.7492694369305175
# Step 10, Loss: 2.8863598969871784
# Step 20, Loss: 1.754624545048474
# Step 30, Loss: 1.2875241285358985
# Step 40, Loss: 1.0420639334500452
#
#
#
#
# Starting point: [[ 0. 10.]], Learning rate: 0.5, Batch size: 5
# Step 0, Loss: 7.6815946312904
# Step 10, Loss: 3.1328430253182926
# Step 20, Loss: 3.2625886998769484
# Step 30, Loss: 1.5397782230657153
# Step 40, Loss: 1.3566949737372465
#
#
#
#
# Starting point: [[ 0. 10.]], Learning rate: 0.5, Batch size: 10
# Step 0, Loss: 7.445693523943423
# Step 10, Loss: 10.404495020360832
# Step 20, Loss: 1.3841327137786967
# Step 30, Loss: 1.4299880151188011
# Step 40, Loss: 1.842079712417924
#
#
#
#
# Starting point: [[ 0. 10.]], Learning rate: 0.5, Batch size: 30
# Step 0, Loss: 5.517186231836272
# Step 10, Loss: 4.15447279676287
# Step 20, Loss: 7.9661612967759
# Step 30, Loss: 4.176007104024215
# Step 40, Loss: 6.923976491016759
#
#
#
#
# Starting point: [[ 0. 10.]], Learning rate: 0.8, Batch size: 5
# Step 0, Loss: 5.504367157678277
# Step 10, Loss: 5.123134109957711
# Step 20, Loss: 4.146149449287016
# Step 30, Loss: 2.2032079439185974
# Step 40, Loss: 0.9791319248115373
#
#
#
#
# Starting point: [[ 0. 10.]], Learning rate: 0.8, Batch size: 10
# Step 0, Loss: 11.226884738346985
# Step 10, Loss: 14.851814753361607
# Step 20, Loss: 5.862160688916989
# Step 30, Loss: 5.50910007537385
# Step 40, Loss: 5.127086077100142
#
#
#
#
# Starting point: [[ 0. 10.]], Learning rate: 0.8, Batch size: 30
# Step 0, Loss: 7.121214032749825
# Step 10, Loss: 8.405345177191887
# Step 20, Loss: 4.422485259385405
# Step 30, Loss: 4.7516037418648045
# Step 40, Loss: 4.964765061300099
#
#
#
#
# Starting point: [[5. 5.]], Learning rate: 0.1, Batch size: 5
# Step 0, Loss: 12.729231905764479
# Step 10, Loss: 7.648315617960298
# Step 20, Loss: 6.593893057396227
# Step 30, Loss: 6.68271869439438
# Step 40, Loss: 6.577543662187537
#
#
#
#
# Starting point: [[5. 5.]], Learning rate: 0.1, Batch size: 10
# Step 0, Loss: 13.407657074858228
# Step 10, Loss: 7.515098087005664
# Step 20, Loss: 6.693638031093691
# Step 30, Loss: 6.661425570208252
# Step 40, Loss: 6.61506572625311
#
#
#
#
# Starting point: [[5. 5.]], Learning rate: 0.1, Batch size: 30
# Step 0, Loss: 11.773931482060325
# Step 10, Loss: 6.558595106756918
# Step 20, Loss: 6.535624983579684
# Step 30, Loss: 6.529632815412564
# Step 40, Loss: 6.528243458251289
#
#
#
#
# Starting point: [[5. 5.]], Learning rate: 0.5, Batch size: 5
# Step 0, Loss: 10.297660752607797
# Step 10, Loss: 6.926303455751941
# Step 20, Loss: 6.745899942623659
# Step 30, Loss: 6.626607641311095
# Step 40, Loss: 6.598821888204043
#
#
#
#
# Starting point: [[5. 5.]], Learning rate: 0.5, Batch size: 10
# Step 0, Loss: 13.19081862193844
# Step 10, Loss: 10.397040655926773
# Step 20, Loss: 6.602767009480155
# Step 30, Loss: 7.667940999723834
# Step 40, Loss: 6.037297536944522
#
#
#
#
# Starting point: [[5. 5.]], Learning rate: 0.5, Batch size: 30
# Step 0, Loss: 6.8626799118112665
# Step 10, Loss: 6.078179306497432
# Step 20, Loss: 6.030649767907813
# Step 30, Loss: 5.89248255581886
# Step 40, Loss: 5.415017757906144
#
#
#
#
# Starting point: [[5. 5.]], Learning rate: 0.8, Batch size: 5
# Step 0, Loss: 7.794820964081772
# Step 10, Loss: 6.183116333897464
# Step 20, Loss: 6.170823747407096
# Step 30, Loss: 6.4092508972361255
# Step 40, Loss: 6.104434934603813
#
#
#
#
# Starting point: [[5. 5.]], Learning rate: 0.8, Batch size: 10
# Step 0, Loss: 9.864222701291316
# Step 10, Loss: 6.035805319650952
# Step 20, Loss: 5.475995989719831
# Step 30, Loss: 5.396283955485007
# Step 40, Loss: 5.396336023124449
#
#
#
#
# Starting point: [[5. 5.]], Learning rate: 0.8, Batch size: 30
# Step 0, Loss: 7.881015917508895
# Step 10, Loss: 5.716416522722053
# Step 20, Loss: 5.385517836783788
# Step 30, Loss: 5.382734020535444
# Step 40, Loss: 5.382350798478726

# %%
# TODO -- Add a learning rate schedule.  Reduce the learning rate by a factor of beta every M iterations
def stochastic_gradient_descent_step_with_schedule(phi, data, alpha, batch_size):
    # Compute the gradient of the loss function
    gradient = compute_gradient(data[0, :], data[1, :], phi)
    # Update the parameters phi by taking a step in the direction opposite to the gradient
    phi = phi - alpha * gradient
    return phi

# Initialize parameters
n_steps = 41
phi_all = np.zeros((2, n_steps+1))
phi_all[:, 0] = [3.5, 6.5]  # Starting parameters
alpha = 0.8  # Initial learning rate
beta = 0.9  # Factor to reduce learning rate by
M = 10  # Reduce learning rate every M iterations
batch_size = 5

# Loop to perform SGD steps with learning rate schedule
for c_step in range(n_steps):
    if c_step % M == 0 and c_step > 0:
        alpha *= beta  # Update learning rate according to the schedule
    phi_all[:, c_step+1:c_step+2] = stochastic_gradient_descent_step_with_schedule(phi_all[:, c_step:c_step+1], data, alpha, batch_size)

    # Optional: Print and visualize the model periodically
    if c_step % 8 == 0:
        loss = compute_loss(data[0,:], data[1,:], model, phi_all[:, c_step+1:c_step+2])
        print(f"Iteration {c_step+1}, Learning rate: {alpha:.4f}, Loss: {loss:.4f}")
        draw_model(data, model, phi_all[:, c_step+1], f"Iteration {c_step+1}, Loss: {loss:.4f}")

# Visualize the final model and loss landscape
draw_model(data, model, phi_all[:, -1], "Final parameters")
draw_loss_function(compute_loss, data, model, phi_all)
# Out:
# Iteration 1, Learning rate: 0.8000, Loss: 10.0523
# Iteration 9, Learning rate: 0.8000, Loss: 5.7589
# Iteration 17, Learning rate: 0.7200, Loss: 5.3906
# Iteration 25, Learning rate: 0.6480, Loss: 5.3825
# Iteration 33, Learning rate: 0.5832, Loss: 5.3819
# Iteration 41, Learning rate: 0.5249, Loss: 5.3817
